# %% [markdown]
# # MCP Services Creation

# %%
import os
import json

import pandas as pd
import numpy as np


from pprint import pprint
from langchain_openai import  AzureChatOpenAI, ChatOpenAI
from dotenv import load_dotenv
from sqlalchemy import (
    create_engine, Column, Integer, String, Float, Date, Boolean, Text, JSON
)
from sqlalchemy.orm import declarative_base, sessionmaker
from sqlalchemy.schema import DDL, CheckConstraint
from tools.prompt import generate_few_shot_ner_prompts
from tools.schema import (
    NERDecisao,
    Obrigacao
)

from datetime import timedelta


load_dotenv()

gpt4turbo = AzureChatOpenAI(
    deployment_name="gpt-4-turbo",
    model_name="gpt-4",
)

'''
gpt4turbo = ChatOpenAI(
    model="gpt-4-turbo",
    temperature=0.0
)
'''

extractor_gpt4turbo = gpt4turbo.with_structured_output(NERDecisao, include_raw=False, method="json_schema")
extractor_obrigacao_gpt4turbo = gpt4turbo.with_structured_output(
    Obrigacao, include_raw=False, method="json_schema")


def safe_int(value):
    if pd.isna(value):
        return None
    return int(value)
# Out:
# c:\Users\05911205424\Documents\Dev\decicontas.br\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1784: UserWarning: Cannot use method='json_schema' with model gpt-4 since it doesn't support OpenAI's Structured Output API. You can see supported models here: https://platform.openai.com/docs/guides/structured-outputs#supported-models. To fix this warning, set `method='function_calling'. Overriding to method='function_calling'.
#   warnings.warn(

# %%
import pymssql
from sqlalchemy.engine import Engine
def get_connection(db: str = 'processo') -> Engine:
    load_dotenv()
    
    server = os.getenv("SQL_SERVER_HOST")
    user = os.getenv("SQL_SERVER_USER")
    password = os.getenv("SQL_SERVER_PASS")
    port = os.getenv("SQL_SERVER_PORT", "1433")  # default MSSQL port
    database = db

    # Construct connection string for SQLAlchemy using pymssql
    connection_string = f"mssql+pymssql://{user}:{password}@{server}/{database}"

    # Create and return SQLAlchemy engine
    engine = create_engine(connection_string)
    return engine

# %%
sql_unidades = """
SELECT [IdUnidadeJurisdicionada]
      ,[NomeUnidade]
  FROM [BdSIAI].[dbo].[Anexo42_UnidadeJurisdicionada]
"""
df_unidades = pd.read_sql(sql_unidades, get_connection('BdSIAI'))

# %%
sql_citacoes = """
SELECT cit.*
  FROM [processo].[dbo].[Cit_Citacoes] AS cit
  WHERE CONCAT(cit.Numero_Processo, '/', cit.Ano_Processo) = '{}'
"""

# %%
sql_obrigacoes = """
SELECT o.*, p.Numero_Processo, p.Ano_Processo, CONCAT(p.Numero_Processo, '/', p.Ano_Processo) AS Processo
FROM BdDIP.dbo.Obrigacao o
INNER JOIN processo.dbo.Processos p
ON o.IdProcesso = p.IdProcesso 
"""
df_obrigacoes = pd.read_sql(sql_obrigacoes, get_connection('BdDIP'))

# %%
def get_responsible_unit(id_unit: int) -> pd.DataFrame:
    sql_resp = """
    SELECT DISTINCT resp.Nome,
        uni.IdUnidadeJurisdicionada,
        uni.NomeUnidade,
        respuni.Cargo,
        respuni.DataInclusao,
        respuni.DataInicioGestao,
        respuni.DataTerminoGestao
    FROM [BdSIAI].[dbo].[Anexo42_Responsavel] resp
    INNER JOIN [BdSIAI].[dbo].[Anexo42_ResponsavelUnidade] respuni ON resp.IdResponsavel = respuni.IdResponsavel
    INNER JOIN [BdSIAI].[dbo].[Anexo42_UnidadeJurisdicionada] uni ON uni.IdUnidadeJurisdicionada = respuni.IdUnidadeJurisdicionada 
        WHERE uni.IdUnidadeJurisdicionada = {}
    """

    return pd.read_sql(sql_resp.format(id_unit), get_connection('BdSIAI'))

# %%
import unicodedata
from rapidfuzz import process, fuzz  # pip install rapidfuzz

def normalizar_texto(s: str) -> str:
    if not isinstance(s, str):
        s = str(s)
    s = s.strip().upper()
    # Remove acentos
    s = unicodedata.normalize("NFKD", s)
    s = "".join(ch for ch in s if not unicodedata.combining(ch))
    return s

def encontrar_unidade(query: str, df_unidades, limite=5, score_cutoff=70):
    """
    Retorna as melhores correspondências de NomeUnidade para a string `query`.
    """
    # Garante cópia para não alterar o original
    df = df_unidades.copy()
    
    # Coluna normalizada (pode salvar de vez no DF se quiser)
    df["NomeUnidade_norm"] = df["NomeUnidade"].apply(normalizar_texto)
    query_norm = normalizar_texto(query)

    # Monta lista de opções a comparar
    nomes_norm = df["NomeUnidade_norm"].tolist()

    # Busca fuzzy
    resultados = process.extract(
        query_norm,
        nomes_norm,
        scorer=fuzz.WRatio,
        limit=limite,
        score_cutoff=score_cutoff,
    )

    # `resultados` é uma lista de tuplas: (string_match, score, índice)
    indices = [idx for _, _, idx in resultados]

    # Retorna subset com score
    df_result = df.iloc[indices].copy()
    df_result["score"] = [score for _, score, _ in resultados]
    # Ordena do melhor para o pior
    df_result = df_result.sort_values("score", ascending=False)

    # Só interessa as colunas originais + score
    return df_result[["IdUnidadeJurisdicionada", "NomeUnidade", "score"]]

# %%
matches1 = encontrar_unidade(
    "instituto de previdência social do rio grande do norte",
    df_unidades,
)
print(matches1.iloc[0]['IdUnidadeJurisdicionada'], matches1.iloc[0]['NomeUnidade'], matches1.iloc[0]['score'])
# Out:
# 19 INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO ESTADO DO RIO GRANDE DO NORTE 88.0

# %%
import re
import unicodedata

# slugify helper
def slugify(name: str) -> str:
    if pd.isna(name):
        return ""
    s = str(name)
    s = unicodedata.normalize("NFKD", s)
    s = "".join(ch for ch in s if not unicodedata.combining(ch))
    s = s.lower()
    s = re.sub(r"[^\w\s-]", "", s)        # remove punctuation
    s = re.sub(r"[\s_-]+", "_", s)        # spaces and dashes -> underscore
    s = s.strip("_")
    return s or "col"

# build new unique column names
old_cols = list(df_obrigacoes.columns)
slugged = [slugify(c) for c in old_cols]

seen = {}
unique_cols = []
for name in slugged:
    count = seen.get(name, 0)
    if count:
        new_name = f"{name}_{count}"
    else:
        new_name = name
    seen[name] = count + 1
    unique_cols.append(new_name)

# apply to dataframe and show result
col_mapping = dict(zip(old_cols, unique_cols))
df_obrigacoes.rename(columns=col_mapping, inplace=True)

# quick check
print(df_obrigacoes.columns.tolist())
df_obrigacoes.head(3)
# Out:
# ['idobrigacao', 'idprocesso', 'idcomposicaopauta', 'idvotopauta', 'descricaoobrigacao', 'defazer', 'prazo', 'datacumprimento', 'orgaoresponsavel', 'idorgaoresponsavel', 'temmultacominatoria', 'nomeresponsavelmultacominatoria', 'documentoresponsavelmultacominatoria', 'idpessoamultacominatoria', 'valormultacominatoria', 'periodomultacominatoria', 'emultacominatoriasolidaria', 'solidariosmultacominatoria', 'cancelado', 'numero_processo', 'ano_processo', 'processo']
#    idobrigacao  idprocesso  idcomposicaopauta  idvotopauta  \
# 0          870       50964             116424        40909
# 1          897       19456             117592        42069
# 2          900       45183             117629        42117
#
#                                   descricaoobrigacao  defazer  \
# 0  a Secretaria de Estado da Agricultura, da Pecu...     True
# 1  Após o trânsito em julgado deste decisum, reme...     True
# 2  Com a publicação desta Decisão, o processo dev...     True
#
#                                           prazo datacumprimento  \
# 0  prazos razoáveis e previamente estabelecidos            None
# 1                                          None            None
# 2                                          None            None
#
#                                     orgaoresponsavel  idorgaoresponsavel  ...  \
# 0  SECRETARIA DA AGRICULTURA, DA PECUÁRIA E DA PESCA                 NaN  ...
# 1                Diretoria de Atos e Execuções (DAE)                 NaN  ...
# 2                                       Desconhecido                 NaN  ...
#
#    documentoresponsavelmultacominatoria idpessoamultacominatoria  \
# 0                                  None                      NaN
# 1                                  None                      NaN
# 2                                  None                      NaN
#
#   valormultacominatoria  periodomultacominatoria  emultacominatoriasolidaria  \
# 0                   NaN                     None                       False
# 1                   NaN                     None                       False
# 2                   NaN                     None                       False
#
#   solidariosmultacominatoria  cancelado numero_processo ano_processo  \
# 0                       null       None          003507         2006
# 1                       null       None          001372         2002
# 2                       null       None          003124         1999
#
#       processo
# 0  003507/2006
# 1  001372/2002
# 2  003124/1999
#
# [3 rows x 22 columns]

# %%
df_obrigacoes
# Out:
#       idobrigacao  idprocesso  idcomposicaopauta  idvotopauta  \
# 0             870       50964             116424        40909
# 1             897       19456             117592        42069
# 2             900       45183             117629        42117
# 3             221       40404             107805        34682
# 4             490       73410             115301        39671
# ...           ...         ...                ...          ...
# 1248         1652      611312             122255        45485
# 1249         1744      615866             123214        45960
# 1250         1745      615866             123214        45960
# 1251         1746      615866             123214        45960
# 1252         1743      615866             123214        45960
#
#                                      descricaoobrigacao  defazer  \
# 0     a Secretaria de Estado da Agricultura, da Pecu...     True
# 1     Após o trânsito em julgado deste decisum, reme...     True
# 2     Com a publicação desta Decisão, o processo dev...     True
# 3     NOTIFICAÇÃO do Instituto de Previdência respon...     True
# 4     NOTIFICAÇÃO do Instituto de Previdência dos Se...     True
# ...                                                 ...      ...
# 1248  Determinar à Diretoria de Controle de Contas d...     True
# 1249  NOTIFICAÇÃO desta decisão ao Ministério Públic...     True
# 1250  Abertura da fase dialógica, por meio da citaçã...     True
# 1251  INTIMAÇÃO da presente decisão às partes envolv...     True
# 1252  INTIMAÇÃO da presente decisão às partes envolv...     True
#
#                                              prazo datacumprimento  \
# 0     prazos razoáveis e previamente estabelecidos            None
# 1                                             None            None
# 2                                             None            None
# 3                                             None            None
# 4                                          60 dias      2024-07-15
# ...                                            ...             ...
# 1248                                          None            None
# 1249                                          None            None
# 1250                              prazo regimental            None
# 1251                                          None            None
# 1252                                          None            None
#
#                                        orgaoresponsavel  idorgaoresponsavel  \
# 0     SECRETARIA DA AGRICULTURA, DA PECUÁRIA E DA PESCA                 NaN
# 1                   Diretoria de Atos e Execuções (DAE)                 NaN
# 2                                          Desconhecido                 NaN
# 3     INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO EST...               536.0
# 4     INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO EST...               536.0
# ...                                                 ...                 ...
# 1248  SECRETARIA DE ESTADO DA EDUCAÇÃO, DA CULTURA, ...               513.0
# 1249             SECRETARIA MUNICIPAL DE SAÚDE DE NATAL              1276.0
# 1250             SECRETARIA MUNICIPAL DE SAÚDE DE NATAL              1276.0
# 1251             SECRETARIA MUNICIPAL DE SAÚDE DE NATAL              1276.0
# 1252             SECRETARIA MUNICIPAL DE SAÚDE DE NATAL              1276.0
#
#       ...  documentoresponsavelmultacominatoria idpessoamultacominatoria  \
# 0     ...                                  None                      NaN
# 1     ...                                  None                      NaN
# 2     ...                                  None                      NaN
# 3     ...                                  None                      NaN
# 4     ...                                  None                      NaN
# ...   ...                                   ...                      ...
# 1248  ...                                  None                      NaN
# 1249  ...                                  None                      NaN
# 1250  ...                                  None                      NaN
# 1251  ...                                  None                      NaN
# 1252  ...                                  None                      NaN
#
#      valormultacominatoria  periodomultacominatoria  \
# 0                      NaN                     None
# 1                      NaN                     None
# 2                      NaN                     None
# 3                      NaN                     None
# 4                      NaN                     None
# ...                    ...                      ...
# 1248                   NaN                     None
# 1249                   NaN                     None
# 1250                   NaN                     None
# 1251                   NaN                     None
# 1252                   NaN                     None
#
#       emultacominatoriasolidaria solidariosmultacominatoria  cancelado  \
# 0                          False                       null       None
# 1                          False                       null       None
# 2                          False                       null       None
# 3                          False                       null       None
# 4                          False                       null       None
# ...                          ...                        ...        ...
# 1248                       False                       null       None
# 1249                       False                       null       None
# 1250                       False                       null       None
# 1251                       False                       null       None
# 1252                       False                       null       None
#
#      numero_processo ano_processo     processo
# 0             003507         2006  003507/2006
# 1             001372         2002  001372/2002
# 2             003124         1999  003124/1999
# 3             002804         2007  002804/2007
# 4             005194         2000  005194/2000
# ...              ...          ...          ...
# 1248          301005         2025  301005/2025
# 1249          002551         2025  002551/2025
# 1250          002551         2025  002551/2025
# 1251          002551         2025  002551/2025
# 1252          002551         2025  002551/2025
#
# [1253 rows x 22 columns]

# %%
obrigacao = df_obrigacoes[~df_obrigacoes['nomeresponsavelmultacominatoria'].isna()].iloc[0]
processo = obrigacao.processo

# %%
processo
# Out:
# '006846/2003'

# %%
df_citacoes = pd.read_sql(sql_citacoes.format(processo), get_connection('processo'))

# %%
df_citacoes.columns
# Out:
# Index(['Numero_Citacao', 'Ano_citacao', 'Sequencia', 'Numero_Processo',
#        'Ano_Processo', 'Orgao', 'Nome', 'Logradouro', 'Complemento_Endereco',
#        'Bairro', 'Cidade', 'UF', 'CEP', 'Tipo', 'Data_envio_AR',
#        'Data_Inicio_Prazo_Resposta', 'Data_final_Prazo_resposta', 'Texto',
#        'Data_chegada_resposta_DE', 'numero_processo_resposta',
#        'ano_processo_resposta', 'Usuario_recebeu_resposta', 'Data_Resposta',
#        'Procedimento', 'Observacao_procedimento', 'prazoProrrogacao',
#        'numero_processo_solicitacao_prorrogacao',
#        'ano_processo_solicitacao_prorrogacao', 'data_solicitacao_prorrogacao',
#        'IdSessao', 'DataInclusao', 'UsuarioInclusao', 'InformacaoGerada',
#        'IdCitacao', 'IdComunicacaoEletronica', 'CoditoTipoProcessoResposta',
#        'IdPessoa', 'IdInformacao', 'NumeroPostagem', 'DataInicioContagem',
#        'ProrrogacaoPrazo', 'ProrrogacaoPrazoDias', 'NovaDataInicial',
#        'ComunicacaoPorEdital', 'TeveRecusa', 'DataPublicacaoDOE',
#        'DataFinalResposta', 'DocumentoOab', 'ufOab', 'IdProcesso',
#        'IdAtaTextoPadrao', 'DataEnvioComunicacaoEletronica',
#        'UsuarioRecebimentoComunicacaoEletronica', 'Rascunho', 'Destinatario',
#        'IdPais', 'ZipCode', 'LogradouroInternacional', 'IdCertidao',
#        'IdItemCertidao', 'IdDocumentoContrafe', 'ObservacaoCertidao',
#        'IdInformacaoCertidaoRecebimento', 'DataExclusao', 'UsuarioExclusao',
#        'IdComunicacaoTipoSituacao', 'DescricaoJustificativaCorrecao',
#        'DescricaoAlerta', 'IdInformacaoDeterminacao', 'Prazo', 'PrazoTipo',
#        'IdComunicacaoTipoEnvio', 'IdSetorInclusao', 'IdDiligenciaPai',
#        'IdCitacaoPai', 'IdTipoComunicacao', 'IsRecusaRecebimento',
#        'IdSessaoOperacao'],
#       dtype='object')

# %%
df_citacoes
# Out:
#   Numero_Citacao Ano_citacao  Sequencia Numero_Processo Ano_Processo  \
# 0         000635        2019          1          006846         2003
# 1         001511        2024          1          006846         2003
# 2         002898        2023          1          006846         2003
# 3         002899        2023          1          006846         2003
# 4         002900        2023          1          006846         2003
# 5         002901        2023          1          006846         2003
# 6         002902        2023          1          006846         2003
# 7         002917        2023          1          006846         2003
#
#         Orgao                                               Nome  \
# 0  SEARH                                Pedro Dantas de Medeiros
# 1  SEARH       Instituto de Previdência Social do Rio Grande ...
# 2  SEARH                                Pedro Dantas de Medeiros
# 3  SEARH       Instituto de Previdência Social do Rio Grande ...
# 4  SEARH       Ministerio Publico do Estado do Rio Grande do ...
# 5  SEARH       RAIMUNDO BEVENUTO DA SILVA (Pedro Dantas de Me...
# 6  SEARH       francisca margareth da silva coelho xavier (Pe...
# 7       SEARH                           supremo tribunal federal
#
#                                           Logradouro Complemento_Endereco  \
# 0                   Rua Kerginaldo Cavalcante nº 582                 None
# 1                                 Rua Jundiaí nº 410                 None
# 2                   Rua Kerginaldo Cavalcante nº 582                 None
# 3                                 Rua Jundiaí nº 410                 None
# 4          Rua Promotor Manoel Alves Pessoa Neto, 97                 None
# 5                           RUA RAIMUNDO CHAVES 1570             sala 206
# 6                           RUA RAIMUNDO CHAVES 1570             sala 206
# 7  Praça dos três Poderes, no setor de Admt. Fede...                 None
#
#                            Bairro  ... IdInformacaoDeterminacao Prazo  \
# 0                 Nova Descoberta  ...                     None  None
# 1                           Tirol  ...                     None  None
# 2                 Nova Descoberta  ...                     None  None
# 3                           Tirol  ...                     None  None
# 4                      Candelaria  ...                     None  None
# 5                      CANDELÁRIA  ...                     None  None
# 6                      CANDELÁRIA  ...                     None  None
# 7  GABINETE MINISTRO DIAS TOFFOLI  ...                     None  None
#
#   PrazoTipo IdComunicacaoTipoEnvio IdSetorInclusao IdDiligenciaPai  \
# 0      None                   None            None            None
# 1      None                   None            None            None
# 2      None                   None            None            None
# 3      None                   None            None            None
# 4      None                   None            None            None
# 5      None                   None            None            None
# 6      None                   None            None            None
# 7      None                   None            None            None
#
#   IdCitacaoPai IdTipoComunicacao IsRecusaRecebimento IdSessaoOperacao
# 0         None              None                None             None
# 1         None              None                None             None
# 2         None              None                None             None
# 3         None              None                None             None
# 4         None              None                None             None
# 5         None              None                None             None
# 6         None              None                None             None
# 7         None              None                None             None
#
# [8 rows x 78 columns]

# %%
obrigacao['orgaoresponsavel'].lower()
# Out:
# 'instituto de previdência social do rio grande do norte'

# %%
obrigacao['nomeresponsavelmultacominatoria']
# Out:
# 'SECRETARIA DE ESTADO DA ADMINISTRAÇÃO E RECURSO HUMANOS'

# %%
id_unidade = encontrar_unidade(obrigacao['orgaoresponsavel'], df_unidades).iloc[0]['IdUnidadeJurisdicionada']

# %%
get_responsible_unit(id_unidade)
# Out:
#                                  Nome  IdUnidadeJurisdicionada  \
# 0      Demétrius Fernandes dos Santos                       19
# 1  GERALDO LAURENTINO DA SILVA JÚNIOR                       19
# 2        JOSÉ MARLÚCIO DIÓGENES PAIVA                       19
# 3         LINAURA MARIA FREIRE SANTOS                       19
# 4              NEREU BATISTA LINHARES                       19
# 5          RICARDO LUIZ PEREIRA PINTO                       19
# 6          RICARDO LUIZ PEREIRA PINTO                       19
# 7                    Tália Maia Lopes                       19
#
#                                          NomeUnidade  \
# 0  INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO EST...
# 1  INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO EST...
# 2  INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO EST...
# 3  INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO EST...
# 4  INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO EST...
# 5  INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO EST...
# 6  INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO EST...
# 7  INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO EST...
#
#                                                Cargo        DataInclusao  \
# 0  Coord. de Concessão de Benefícios Previdenciários 2018-12-17 08:10:00
# 1                        ASSESSOR JURÍDICO 1ª CLASSE 2018-12-17 08:10:00
# 2                                         PRESIDENTE 2018-12-17 08:10:00
# 3                                  Chefe de Gabinete 2020-03-11 14:16:00
# 4                                         PRESIDENTE 2019-01-09 13:25:00
# 5                                  ASSESSOR JURÍDICO 2018-04-03 10:12:00
# 6                                  Assessor Jurídico 2018-12-17 08:10:00
# 7                                  Procuradora Geral 2018-12-17 08:10:00
#
#   DataInicioGestao DataTerminoGestao
# 0       2018-11-28        2018-12-31
# 1       2015-01-29        2018-03-26
# 2       2015-01-01        2018-12-31
# 3       2019-02-19              None
# 4       2019-01-08              None
# 5       2018-03-27              None
# 6       2018-03-27        2018-04-11
# 7       2018-04-12        2018-11-06

# %%
obrigacao
# Out:
# idobrigacao                                                                           785
# idprocesso                                                                          93668
# idcomposicaopauta                                                                  112489
# idvotopauta                                                                         36929
# descricaoobrigacao                      Após cessar a aposentadoria da parte interessa...
# defazer                                                                              True
# prazo                                                                    30 dias corridos
# datacumprimento                                                                2023-12-16
# orgaoresponsavel                        Instituto de Previdência Social do Rio Grande ...
# idorgaoresponsavel                                                                  512.0
# temmultacominatoria                                                                  True
# nomeresponsavelmultacominatoria         SECRETARIA DE ESTADO DA ADMINISTRAÇÃO E RECURS...
# documentoresponsavelmultacominatoria                                       08241788000130
# idpessoamultacominatoria                                                          17229.0
# valormultacominatoria                                                              1000.0
# periodomultacominatoria                                                            diário
# emultacominatoriasolidaria                                                          False
# solidariosmultacominatoria                                                           null
# cancelado                                                                            None
# numero_processo                                                                    006846
# ano_processo                                                                         2003
# processo                                                                      006846/2003
# Name: 5, dtype: object

# %%
print(obrigacao['descricaoobrigacao'])
# Out:
# Após cessar a aposentadoria da parte interessada, desaverbar o período contributivo objeto da Certidão de Tempo de Contribuição emitida pelo INSS e devolvê-la à apontada Autarquia Federal, para que a parte interessada possa requerer, diretamente no INSS, sua aposentadoria, conforme as regras do RGPS, levando a Certidão de Tempo de Contribuição emitida pelo IPERN para averbação junto ao INSS.

# %%
df_unidades.columns
# Out:
# Index(['IdUnidadeJurisdicionada', 'NomeUnidade'], dtype='object')
